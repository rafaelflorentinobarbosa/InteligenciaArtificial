# %% [markdown]
# # Credit Scoring

# %% [markdown]
# # imagem 1
# ![image.png](attachment:image.png)

# %% [markdown]
# # imagem 2
# ![image.png](attachment:image.png)

# %% [markdown]
# # imagem 3
# ![image.png](attachment:image.png)

# %% [markdown]
# # imagem 4
# ![image.png](attachment:image.png)

# %% [markdown]
# # Imagem 5
# ![image.png](attachment:image.png)
